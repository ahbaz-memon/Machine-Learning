# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import cluster
from sklearn.datasets import make_blobs

import seaborn as sns

# %%
data = make_blobs(n_samples = 100,
                  n_features = 2,
                  centers = 5,
                  cluster_std = 0.75,
                  random_state = 6
                 )[0]

# %%
plt.figure(dpi = 500)
plt.title('Data without  clustering')
plt.xlabel('X1')
plt.ylabel('X2')
plt.scatter(data[:, 0], data[:, 1], alpha = 0.75)
plt.show()

# %%
kmeans = cluster.KMeans(n_clusters = 5, 
                        n_jobs = -1
                       )

# %%
kmeans.fit(data)
# Out:
# C:\Users\SALMAN MEMON\anaconda3\envs\tensorflow\lib\site-packages\sklearn\cluster\_kmeans.py:938: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn("'n_jobs' was deprecated in version 0.23 and will be"
# KMeans(n_clusters=5, n_jobs=-1)

# %%
y = kmeans.labels_
y
# Out:
# array([4, 3, 1, 2, 3, 4, 4, 2, 4, 2, 1, 2, 2, 0, 3, 4, 1, 3, 3, 2, 1, 3,
#        4, 1, 3, 0, 0, 3, 2, 2, 1, 0, 2, 3, 1, 0, 4, 3, 2, 0, 1, 2, 2, 4,
#        4, 0, 4, 0, 1, 0, 4, 4, 3, 3, 3, 4, 1, 1, 0, 2, 3, 3, 0, 1, 0, 0,
#        3, 2, 4, 4, 1, 0, 2, 1, 0, 1, 1, 4, 0, 1, 2, 0, 0, 1, 3, 4, 2, 4,
#        2, 0, 4, 2, 1, 3, 3, 3, 4, 2, 0, 1])

# %%
mean_centers = kmeans.cluster_centers_
mean_centers
# Out:
# array([[ 0.51820157, -1.65334685],
#        [ 8.06164146, -3.33557003],
#        [-3.41213083,  2.6299032 ],
#        [ 6.43872996, -9.0535452 ],
#        [-7.83099397,  1.78145787]])

# %%
plt.figure(dpi = 500)

plt.title('Data with clustering')
plt.xlabel('X1')
plt.ylabel('X2')

plt.scatter(mean_centers[:, 0], 
            mean_centers[:, 1], 
            c = 'k',
            alpha = 1,
            marker = '*'
           )
plt.scatter(data[:, 0], 
            data[:, 1], 
            c = y,
            alpha = 0.75,
           )

plt.show()
